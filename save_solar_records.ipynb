# %%
import solar_sensor_env
import matplotlib.pyplot as plt
import seaborn as sns
import functools
import datetime

# %%
fig,ax = plt.subplots(1)
ax.plot(trainingmonth[:-1],train)
sns.despine()

# %%
fig,ax = plt.subplots(1)
ax.plot(test)
sns.despine()
